# %%
doc_block = "the agent's phone number is 408-555-1234. call soon!"

# %%
"phone" in doc_block
# Out:
# True

# %%
import re

# %%
pattern ="phone"
re.search(pattern , doc_block)
# Out:
# <re.Match object; span=(12, 17), match='phone'>

# %%
pattern = "not in text"
re.search(pattern,doc_block)

# %%
pattern ="phone"
match =re.search(pattern , doc_block)

# %%
match
# Out:
# <re.Match object; span=(12, 17), match='phone'>

# %%
print(match.span())
print(match.start())
print(match.end())
# Out:
# (12, 17)
# 12
# 17

# %%
doc_block= "my phone is new phone"
match = re.search("phone",doc_block)

# %%
match
# Out:
# <re.Match object; span=(3, 8), match='phone'>

# %%
match.span()
# Out:
# (3, 8)

# %%
matches = re.findall("phone" , doc_block)
matches
# Out:
# ['phone', 'phone']

# %%
len(matches)
# Out:
# 2

# %%
for match in re.finditer("phone",doc_block):
    print(match.span())
# Out:
# (3, 8)
# (16, 21)

# %% [markdown]
# #to find the pattern

# %%
doc_block = "my phone number is 408-555-1234"

# %%
phone = re.search(r'\d\d\d-' , doc_block)
phone.group()
# Out:
# '408-'

# %%
for phone in re.finditer(r'\d\d\d-' , doc_block):
    print(phone.group())
# Out:
# 408-
# 555-

# %%
phone_pp = re.compile(r'(\d{3})-(\d{3})-(\d{4})')
re.search(phone_pp,doc_block).group()
# Out:
# '408-555-1234'

# %%
print(re.search(phone_pp,doc_block).group(1))
print(re.search(phone_pp,doc_block).group(2))
print(re.search(phone_pp,doc_block).group(3))
# Out:
# 408
# 555
# 1234

# %%
phone_pp = re.compile(r'(\d{3})-')
re.search(phone_pp,doc_block).group()
# Out:
# '408-'

# %%
print(re.search(phone_pp,doc_block).group(1))
print(re.search(phone_pp,doc_block).group(2))
print(re.search(phone_pp,doc_block).group(3))
# Out:
# 408
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 print(re.search(phone_pp,doc_block).group(1))
# ----> 2 print(re.search(phone_pp,doc_block).group(2))
#       3 print(re.search(phone_pp,doc_block).group(3))
#
# IndexError: no such group

# %%
re.search(r'man|women' , 'this women was here ')

# %%
re.search(r'man|women' , 'this kartik is here ')

# %%
re.findall(r'.at' , 'the cat in the hat sat here')

# %%
re.findall(r'.at' , 'the bat went splat')

# %%
re.findall(r'...at' , 'the bat went splat')

# %%
re.findall(r'\S+at' , 'the bat went splat')

# %% [markdown]
# #start with and end with

# %%
re.findall(r'\d$' , '1 this end with a number 290')

# %%
re.findall(r'^\d' , '1 this start with a number 2 ')

# %% [markdown]
# #exclusion

# %% [markdown]
# to eclude char , we can use the ^ symbol is conjunction with a set of brackets [] . anything inside thr [] , is excluded

# %%
pharse =" therr are 3 number 34 inside 5 this sentence "

# %%
re.findall(r'[^\d]' , pharse)

# %%
re.findall(r'[^\d]+' , pharse)

# %%
test_phrse = ' this is a string ! but it has punctuation . how can we remove it?'

# %%
re.findall(r'[^!.? ]+' , test_phrse)

# %%
re.findall(r'[^!.?]+' , test_phrse)

# %%
clean = " ".join(re.findall(r'[^!.? ]+' , test_phrse))
clean

# %%
clean

# %% [markdown]
# brackets for grouping

# %%
doc_block = "only find the hypen-word in this sentence. but you do not know how long-ish they are"

# %%
re.findall(r'[\w]+-[\w]+', doc_block)
