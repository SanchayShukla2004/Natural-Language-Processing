# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import spacy
#
# File ~/.local/lib/python3.11/site-packages/spacy/__init__.py:14
#      11 from thinc.api import prefer_gpu, require_gpu, require_cpu  # noqa: F401
#      12 from thinc.api import Config
# ---> 14 from . import pipeline  # noqa: F401
#      15 from .cli.info import info  # noqa: F401
#      16 from .glossary import explain  # noqa: F401
#
# File ~/.local/lib/python3.11/site-packages/spacy/pipeline/__init__.py:1
# ----> 1 from .attributeruler import AttributeRuler
#       2 from .dep_parser import DependencyParser
#       3 from .edit_tree_lemmatizer import EditTreeLemmatizer
#
# File ~/.local/lib/python3.11/site-packages/spacy/pipeline/attributeruler.py:6
#       3 import srsly
#       4 from pathlib import Path
# ----> 6 from .pipe import Pipe
#       7 from ..errors import Errors
# ...

# %%
nlp = spacy.load('en_core_web_sm')

doc = nlp(u'tesla is looking at buying U.S. startup for $6 million')

for token_item in doc:
    print(token_item.doc_block,token_item.pos_ ,token_item.dep_)

# %%
doc2 = nlp(u"Tesla isn't     looking into startups anymore.")
for token_item in doc2:
    print(token_item.doc_block,token_item.pos_ ,token_item.dep_)

# %%
doc2[4]

# %%
type(doc2)

# %%
doc[0].pos_

# %%
doc[0].dep_

# %%
spacy.explain('PROPN')

# %%
spacy.explain(doc[0].dep_)

# %%
doc2[4].doc_block

# %%
doc2[4].lemma_

# %%
doc2[4].pos_

# %%
doc2[4].tag_

# %%
spacy.explain(doc2[4].tag_)

# %%
doc2[4].shape_

# %%
doc2[4].is_alpha

# %%
doc2[4].is_stop

# %%
print(doc2[4].pos_)
print(doc2[4].tag_ +"/"+spacy.explain(doc2[4].tag_))

# %%
print(doc2[0].doc_block +"  _:  "+ doc2[0].shape_)
print(doc[5].doc_block +"  _:  "+ doc2[5].shape_)

# %%
doc3 =nlp(u'although commonly attributed to john lennon from his song "beautiful boy", \
the phrase "Life is what happens to us while we are making other plans " was written by \
 cartoonist Allen Saunders and published in Reader \'s Digest in 1957 , when Lennon was 17.')

# %%
life_quote = doc3[16:30]
print(life_quote)

# %%
type(life_quote)

# %%
doc4 = nlp(u'this is the first sentence. this is another sentence. this is the last sentence')

# %%
for sent in doc4.sents:
    print(sent)

# %%
print(f"'{doc4[6]}'word  --  {doc4[4].is_sent_start}")

# %%
doc4[6].is_stop
