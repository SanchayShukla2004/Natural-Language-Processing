# %%
import nltk
from nltk import word_tokenize

# %% [markdown]
# #NLTK - Natural Language Toolkit
# - is an open source libaray . it provides many functionalities and include pre- trainder model
# - integrates well with othe lib . such as skit- learn

# %% [markdown]
# #NLTK  model

# %%
nltk.download('punkt') # it is pretrained lang_model for tokrnization
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno -3] Temporary
# [nltk_data]     failure in name resolution>
# False

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Error loading punkt_tab: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>
# False

# %% [markdown]
# perform tokenization

# %%
segment = '"Today is friday. Next Week , We’re coming from U.S.!"'

# %%
for token_item in word_tokenize(segment):
  print(token_item)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for token_item in word_tokenize(segment):
#       2   print(token_item)
#
# File ~/.local/lib/python3.11/site-packages/nltk/tokenize/__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File ~/.local/lib/python3.11/site-packages/nltk/tokenize/__init__.py:119, in sent_tokenize(text, language)
# ...

# %%
sent2 = "we're  here to help you! ask the question, email support@abcdnet.ax or visit us at http://www.abc.net.ax! "

# %%
for token_item in word_tokenize(sent2):
  print(token_item)

# %%
sent3 = "we are learning NLP, this is a good course. it weather good today?"

# %%
for token_item in word_tokenize(sent3):
  print(token_item)

# %%
sent3.split()
